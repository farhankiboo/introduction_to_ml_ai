# %% [markdown]
# ### **Machine Learning Week 4**
# ---
# > Introduction to Machine Learning <br>
# > Sekolah Data, Pacmann

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
# Load Dataset
data = pd.read_csv("dataset/w4-1-advertising.csv")
data = data.drop(columns = ["Unnamed: 0"])
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

ax[0].scatter(data["TV"], data["Sales"])
ax[1].scatter(data["Radio"], data["Sales"])
ax[2].scatter(data["Newspaper"], data["Sales"])

ax[0].set_xlabel("TV")
ax[1].set_xlabel("Radio")
ax[2].set_xlabel("Newspaper")

ax[0].set_ylabel("sales")
ax[1].set_ylabel("sales")
ax[2].set_ylabel("sales")

plt.show()

# %% [markdown]
# ### **Melakukan Linear Regression dengan sklearn**

# %%
# Import library
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Split input-output

# %%
# Buat input & output
def split_input_output(data, target_column):
    X = data.drop(columns = target_column)
    y = data[target_column]

    return X, y

X, y = split_input_output(data = data,
                          target_column = "Sales")

# %%
X.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: Sales, dtype: float64

# %% [markdown]
# Split train & test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size = 0.2,
                                                    random_state = 123)

# %%
X_train.head()
# Out:
#         TV  Radio  Newspaper
# 24    62.3   12.6       18.3
# 150  280.7   13.9       37.0
# 114   78.2   46.8       34.5
# 33   265.6   20.0        0.3
# 23   228.3   16.9       26.2

# %% [markdown]
# Tentukan baseline model
#
# - Baseline model regresi adalah rata-rata dari target

# %%
baseline_pred = np.mean(y_train) # selalu rata-rata
print(baseline_pred)
# Out:
# 14.095000000000002

# %%
np.ones(len(y_train)) * baseline_pred
# Out:
# array([14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095,
#        14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095, 14.095])

# %%
from sklearn.metrics import mean_squared_error

baseline_mse = mean_squared_error(y_train, 
                                  np.ones(len(y_train)) * baseline_pred)
print(baseline_mse)
# Out:
# 26.088974999999998

# %% [markdown]
# Buat Objek & Fitting

# %%
# Buat objek
lr = LinearRegression()

# %%
# Lakukan cross validation
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(estimator = lr,
                         X = X_train,
                         y = y_train,
                         cv = 5,
                         scoring = "neg_mean_squared_error") # kenapa negatif untuk mempermudah hitungan di suatu algoritma (jika mau jadi positif kalikan negatif 1 (* -1))

# %%
scores
# Out:
# array([-1.95519805, -5.9288142 , -2.14412184, -3.06528874, -2.98933228])

# %%
lr_cv_scores = - np.mean(scores) # dikali negatif maka hasilnya positif
print(lr_cv_scores)
# Out:
# 3.216551023140724

# %%
# Lakukan Fitting Data
lr.fit(X = X_train,
       y = y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predict & Evaluate

# %%
# Buat prediksi
y_pred = lr.predict(X_train)

# %%
summary_train_pred = pd.DataFrame({"actual": y_train,
                                   "prediction": y_pred})

summary_train_pred.head()
# Out:
#      actual  prediction
# 24      9.7    8.103212
# 150    16.1   18.290549
# 114    14.6   15.197324
# 33     17.4   18.763145
# 23     15.5   16.468096

# %%
# Plot hasil
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))

ax.scatter(summary_train_pred["actual"], summary_train_pred["prediction"])
ax.plot([0, 30], [0, 30], "--k")

ax.set_xlabel("Actual")
ax.set_ylabel("Prediction")
ax.set_xlim(0, 30)
ax.set_ylim(0, 30)
plt.show()

# %% [markdown]
# - prediksi semakin bagus apabila titik dekat dengan garis putus-putus

# %%
# Cari MSE
prediction_train_mse = mean_squared_error(y_pred, y_train)
print(prediction_train_mse)
# Out:
# 2.9376246773049877

# %%
# Cari perbandingan dengan baseline
comparison_mse = 100*(baseline_mse - prediction_train_mse) / baseline_mse
print(f"MSE turun {comparison_mse:.2f} %")
# Out:
# MSE turun 88.74 %

# %% [markdown]
# Pada Data Test

# %%
# Buat prediksi
y_test_pred = lr.predict(X_test)

# %%
summary_test_pred = pd.DataFrame({"actual": y_test,
                                  "prediction": y_test_pred})

summary_test_pred.head()
# Out:
#      actual  prediction
# 50     11.4   12.589349
# 127     8.8    6.574663
# 37     14.7   15.515691
# 149    10.1    9.761643
# 19     14.6   14.085603

# %%
# Plot hasil
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))

ax.scatter(summary_test_pred["actual"], summary_test_pred["prediction"])
ax.plot([0, 30], [0, 30], "--k")

ax.set_xlabel("Actual")
ax.set_ylabel("Prediction")
ax.set_xlim(0, 30)
ax.set_ylim(0, 30)
plt.show()

# %% [markdown]
# - prediksi semakin bagus apabila titik dekat dengan garis putus-putus

# %%
# Cari MSE
prediction_test_mse = mean_squared_error(y_test_pred, y_test)
print(prediction_test_mse)
# Out:
# 2.20301297910285

# %%
# Cari perbandingan dengan baseline
comparison_mse = 100*(baseline_mse - prediction_test_mse) / baseline_mse
print(f"MSE turun {comparison_mse:.2f} %")
# Out:
# MSE turun 91.56 %

# %% [markdown]
# Tampilkan hasil linear regression

# %%
# Koefisien/slope linear regression
lr.coef_
# Out:
# array([ 0.04558897,  0.18653389, -0.00063032])

# %%
# Intercept linear regression
lr.intercept_
# Out:
# np.float64(2.9242267872501273)

# %% [markdown]
# Persamaan Final
#
# $$
# \text{sales} = 0.046 \cdot \text{TV} + 0.189 \cdot \text{Radio} - 0.001 \cdot \text{Newspaper} + 2.939
# $$
#
# - Akan dapat kenaikan sales kalau tidak melakukan apa-apa (intercept > 0)
# - Ads lewat Radio menyumbang kontribusi besar terhadap sales dibandingkan TV & Newspaper
# - Ads lewat Newspaper hampir "tidak berpengaruh" atau tidak ada hubungan pada Sales

# %% [markdown]
# ### **Melakukan Linear Regression Dari Scratch**

# %% [markdown]
# Kita ingin membuat persamaan linear sebagai berikut
#
# $$
# \text{sales} = \beta_{1} \cdot \text{TV} + \beta_{2} \cdot \text{Radio} + \beta_{3} \cdot \text{Newspaper} + \beta_{0} + e
# $$

# %% [markdown]
# Karena kita memiliki data-nya, maka kita buat saja semua persamaan berdasarkan data.

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# Contoh 3 persamaan pertama
#
# $$
# \begin{align*}
# 22.1 &= \beta_{1} \cdot 230.1 + \beta_{2} \cdot 37.8 + \beta_{3} \cdot 69.2 + \beta_{0} + e_{1}\\
# 10.4 &= \beta_{1} \cdot 44.5 + \beta_{2} \cdot 45.9 + \beta_{3} \cdot 45.1 + \beta_{0} + e_{2} \\
# 9.3 &= \beta_{1} \cdot 17.2 + \beta_{2} \cdot 41.3 + \beta_{3} \cdot 69.3 + \beta_{0} + e_{3} \\
# &\vdots
# \end{align*}
# $$

# %% [markdown]
# Persamaan di atas, dapat diubah menjadi perkalian Matrix & Vektor

# %% [markdown]
# $$
# \begin{bmatrix}
# 22.1\\
# 10.4\\
# 9.3\\
# \vdots
# \end{bmatrix} =
# \begin{bmatrix}
# 230.1 & 37.8 & 69.2 & 1\\
# 44.5 & 45.9 & 45.1 & 1\\
# 17.2 & 41.3 & 69.3 & 1\\
# \vdots & \vdots & \vdots & \vdots
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# \beta_{1}\\
# \beta_{2}\\
# \beta_{3}\\
# \beta_{0}
# \end{bmatrix}
# +
# \begin{bmatrix}
# e_{1}\\
# e_{2}\\
# e_{3}\\
# \vdots
# \end{bmatrix}
# $$

# %% [markdown]
# Lebih umum sebagai berikut

# %% [markdown]
# $$
# \begin{bmatrix}
# \vdots\\
# y\\
# \vdots
# \end{bmatrix} =
# \begin{bmatrix}
# \vdots & \vdots & \vdots & \vdots \\
# \text{TV} & \text{Radio} & \text{Advertising} & 1\\
# \vdots & \vdots & \vdots & \vdots
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# \beta_{1}\\
# \beta_{2}\\
# \beta_{3}\\
# \beta_{0}
# \end{bmatrix}
# +
# \begin{bmatrix}
# \vdots\\
# e\\
# \vdots
# \end{bmatrix}
# $$

# %% [markdown]
# Bisa kita notasikan dalam variable

# %% [markdown]
# $$
# y = X \cdot \theta + e
# $$

# %% [markdown]
# Untuk menyelesaikan ini, kita membuat MSE

# %% [markdown]
# $$
# \begin{align*}
# \text{MSE} &= \cfrac{1}{n} \sum_{i=1}^{n} e_{i}^2\\
# \text{MSE} &= \cfrac{1}{n} (y-X\cdot\theta)^{2}
# \end{align*}
# $$

# %% [markdown]
# - Yang ingin dicari adalah parameter model, $\theta = \{\beta_{0}, \cdots, \beta_{3}\}$ agar MSE minimum.
# - Kita bisa pakai turunan

# %% [markdown]
# $$
# \begin{align*}
# \cfrac{\partial \text{MSE}}{\partial \theta} &= 0 \\
# 0 &= \cfrac{\partial}{\partial \theta} \cfrac{1}{n} (y-X\cdot\theta)^{2} \\
# &= \cfrac{2}{n} (-X^{T}) (y - X \cdot \theta) \\
# &= X^{T}y - (X^{T}X)\theta \\
# \theta_{\text{optimum}} &= (X^{T}X)^{-1} X^{T} y
# \end{align*}
# $$

# %% [markdown]
# - Disebut juga dengan solusi OLS

# %% [markdown]
# - Yuk kita buat

# %%
# Buat matriks X_ols
X_ols = np.column_stack([X_train, np.ones(len(X_train))])
X_ols
# Out:
# array([[ 62.3,  12.6,  18.3,   1. ],
#        [280.7,  13.9,  37. ,   1. ],
#        [ 78.2,  46.8,  34.5,   1. ],
#        [265.6,  20. ,   0.3,   1. ],
#        [228.3,  16.9,  26.2,   1. ],
#        [164.5,  20.9,  47.4,   1. ],
#        [177. ,  33.4,  38.7,   1. ],
#        [222.4,   4.3,  49.8,   1. ],
#        [197.6,  23.3,  14.2,   1. ],
#        [109.8,  14.3,  31.7,   1. ],
#        [139.5,   2.1,  26.6,   1. ],
#        [225.8,   8.2,  56.5,   1. ],
#        [293.6,  27.7,   1.8,   1. ],
#        [141.3,  26.8,  46.2,   1. ],
#        [ 75.5,  10.8,   6. ,   1. ],
#        [ 85.7,  35.8,  49.3,   1. ],
#        [ 66.1,   5.8,  24.2,   1. ],
#        [276.9,  48.9,  41.8,   1. ],
#        [120.5,  28.5,  14.2,   1. ],
#        [239.3,  15.5,  27.3,   1. ],
#        [239.8,   4.1,  36.9,   1. ],
#        [ 90.4,   0.3,  23.2,   1. ],
#        [175.7,  15.4,   2.4,   1. ],
#        [140.3,   1.9,   9. ,   1. ],
#        [  8.6,   2.1,   1. ,   1. ],
#        [121. ,   8.4,  48.7,   1. ],
#        [187.8,  21.1,   9.5,   1. ],
#        [134.3,   4.9,   9.3,   1. ],
#        [266.9,  43.8,   5. ,   1. ],
#        [102.7,  29.6,   8.4,   1. ],
#        [248.8,  27.1,  22.9,   1. ],
#        [ 97.5,   7.6,   7.2,   1. ],
#        [131.7,  18.4,  34.6,   1. ],
#        [ 76.4,  26.7,  22.3,   1. ],
#        [ 93.9,  43.5,  50.5,   1. ],
#        [ 25.1,  25.7,  43.3,   1. ],
#        [ 17.2,   4.1,  31.6,   1. ],
#        [149.8,   1.3,  24.3,   1. ],
#        [  0.7,  39.6,   8.7,   1. ],
#        [ 53.5,   2. ,  21.4,   1. ],
#        [120.2,  19.6,  11.6,   1. ],
#        [292.9,  28.3,  43.2,   1. ],
#        [170.2,   7.8,  35.2,   1. ],
#        [  8.4,  27.2,   2.1,   1. ],
#        [ 70.6,  16. ,  40.8,   1. ],
#        [290.7,   4.1,   8.5,   1. ],
#        [230.1,  37.8,  69.2,   1. ],
#        [286. ,  13.9,   3.7,   1. ],
#        [175.1,  22.5,  31.5,   1. ],
#        [273.7,  28.9,  59.7,   1. ],
#        [202.5,  22.3,  31.6,   1. ],
#        [210.7,  29.5,   9.3,   1. ],
#        [243.2,  49. ,  44.3,   1. ],
#        [ 89.7,   9.9,  35.7,   1. ],
#        [ 87.2,  11.8,  25.9,   1. ],
#        [  8.7,  48.9,  75. ,   1. ],
#        [ 67.8,  36.6, 114. ,   1. ],
#        [284.3,  10.6,   6.4,   1. ],
#        [ 69. ,   9.3,   0.9,   1. ],
#        [213.4,  24.6,  13.1,   1. ],
#        [261.3,  42.7,  54.7,   1. ],
#        [ 38.2,   3.7,  13.8,   1. ],
#        [ 43.1,  26.7,  35.1,   1. ],
#        [240.1,  16.7,  22.9,   1. ],
#        [262.7,  28.8,  15.9,   1. ],
#        [104.6,   5.7,  34.4,   1. ],
#        [ 38. ,  40.3,  11.9,   1. ],
#        [218.5,   5.4,  27.4,   1. ],
#        [163.5,  36.8,   7.4,   1. ],
#        [220.5,  33.2,  37.9,   1. ],
#        [110.7,  40.6,  63.2,   1. ],
#        [199.8,   2.6,  21.2,   1. ],
#        [ 57.5,  32.8,  23.5,   1. ],
#        [172.5,  18.1,  30.7,   1. ],
#        [139.2,  14.3,  25.6,   1. ],
#        [224. ,   2.4,  15.6,   1. ],
#        [234.5,   3.4,  84.8,   1. ],
#        [ 94.2,   4.9,   8.1,   1. ],
#        [206.8,   5.2,  19.4,   1. ],
#        [193.7,  35.4,  75.6,   1. ],
#        [109.8,  47.8,  51.4,   1. ],
#        [237.4,   5.1,  23.5,   1. ],
#        [214.7,  24. ,   4. ,   1. ],
#        [139.3,  14.5,  10.2,   1. ],
#        [151.5,  41.3,  58.5,   1. ],
#        [ 76.3,  27.5,  16. ,   1. ],
#        [215.4,  23.6,  57.6,   1. ],
#        [ 28.6,   1.5,  33. ,   1. ],
#        [ 25.6,  39. ,   9.3,   1. ],
#        [227.2,  15.8,  49.9,   1. ],
#        [ 76.4,   0.8,  14.8,   1. ],
#        [100.4,   9.6,   3.6,   1. ],
#        [ 44.5,  39.3,  45.1,   1. ],
#        [ 69.2,  20.5,  18.3,   1. ],
#        [ 23.8,  35.1,  65.9,   1. ],
#        [248.4,  30.2,  20.3,   1. ],
#        [  7.3,  28.1,  41.4,   1. ],
#        [262.9,   3.5,  19.5,   1. ],
#        [296.4,  36.3, 100.9,   1. ],
#        [206.9,   8.4,  26.4,   1. ],
#        [ 59.6,  12. ,  43.1,   1. ],
#        [187.9,  17.2,  17.9,   1. ],
#        [204.1,  32.9,  46. ,   1. ],
#        [ 36.9,  38.6,  65.6,   1. ],
#        [ 75.1,  35. ,  52.7,   1. ],
#        [232.1,   8.6,   8.7,   1. ],
#        [199.1,  30.6,  38.7,   1. ],
#        [195.4,  47.7,  52.9,   1. ],
#        [240.1,   7.3,   8.7,   1. ],
#        [ 13.2,  15.9,  49.6,   1. ],
#        [ 43. ,  25.9,  20.5,   1. ],
#        [210.8,  49.6,  37.7,   1. ],
#        [ 16.9,  43.7,  89.4,   1. ],
#        [131.1,  42.8,  28.9,   1. ],
#        [216.8,  43.9,  27.2,   1. ],
#        [166.8,  42. ,   3.6,   1. ],
#        [265.2,   2.9,  43. ,   1. ],
#        [ 27.5,   1.6,  20.7,   1. ],
#        [ 95.7,   1.4,   7.4,   1. ],
#        [  4.1,  11.6,   5.7,   1. ],
#        [107.4,  14. ,  10.9,   1. ],
#        [125.7,  36.9,  79.2,   1. ],
#        [184.9,  21. ,  22. ,   1. ],
#        [280.2,  10.1,  21.4,   1. ],
#        [217.7,  33.5,  59. ,   1. ],
#        [229.5,  32.3,  74.2,   1. ],
#        [135.2,  41.7,  45.9,   1. ],
#        [137.9,  46.4,  59. ,   1. ],
#        [ 48.3,  47. ,   8.5,   1. ],
#        [191.1,  28.7,  18.2,   1. ],
#        [168.4,   7.1,  12.8,   1. ],
#        [177. ,   9.3,   6.4,   1. ],
#        [228. ,  37.7,  32. ,   1. ],
#        [213.5,  43. ,  33.8,   1. ],
#        [ 17.2,  45.9,  69.3,   1. ],
#        [198.9,  49.4,  60. ,   1. ],
#        [ 66.9,  11.7,  36.8,   1. ],
#        [237.4,  27.5,  11. ,   1. ],
#        [ 39.5,  41.1,   5.8,   1. ],
#        [117.2,  14.7,   5.4,   1. ],
#        [  5.4,  29.9,   9.4,   1. ],
#        [149.7,  35.6,   6. ,   1. ],
#        [171.3,  39.7,  37.7,   1. ],
#        [241.7,  38. ,  23.2,   1. ],
#        [222.4,   3.4,  13.1,   1. ],
#        [ 97.2,   1.5,  30. ,   1. ],
#        [129.4,   5.7,  31.3,   1. ],
#        [239.9,  41.5,  18.5,   1. ],
#        [283.6,  42. ,  66.2,   1. ],
#        [209.6,  20.6,  10.7,   1. ],
#        [197.6,   3.5,   5.9,   1. ],
#        [136.2,  19.2,  16.6,   1. ],
#        [123.1,  34.6,  12.4,   1. ],
#        [ 25. ,  11. ,  29.7,   1. ],
#        [ 68.4,  44.5,  35.6,   1. ],
#        [281.4,  39.6,  55.8,   1. ],
#        [289.7,  42.3,  51.2,   1. ],
#        [ 31.5,  24.6,   2.2,   1. ],
#        [  7.8,  38.9,  50.6,   1. ],
#        [255.4,  26.9,   5.5,   1. ]])

# %%
# Buat vektor y_ols
y_ols = np.array(y_train)
y_ols
# Out:
# array([ 9.7, 16.1, 14.6, 17.4, 15.5, 14.5, 17.1, 11.7, 16.6, 12.4, 10.3,
#        13.4, 20.7, 15.5,  9.9, 13.3,  8.6, 27. , 14.2, 15.7, 12.3,  8.7,
#        14.1, 10.3,  4.8, 11.6, 15.6, 11.2, 25.4, 14. , 18.9,  9.7, 12.9,
#        11.8, 15.3,  8.5,  5.9, 10.1,  1.6,  8.1, 13.2, 21.4, 11.7,  5.7,
#        10.5, 12.8, 22.1, 15.9, 14.9, 20.8, 16.6, 18.4, 25.4, 10.6, 10.6,
#         7.2, 12.5, 15. ,  9.3, 17. , 24.2,  7.6, 10.1, 15.9, 20.2, 10.4,
#        10.9, 12.2, 18. , 20.1, 16. , 10.6, 11.8, 14.4, 12.2, 11.6, 11.9,
#         9.7, 12.2, 19.2, 16.7, 12.5, 17.4, 13.4, 18.5, 12. , 17.1,  7.3,
#         9.5, 14.8,  9.4, 10.7, 10.4, 11.3,  9.2, 20.2,  5.5, 12. , 23.8,
#        12.9,  9.7, 14.7, 19. , 10.8, 12.6, 13.4, 18.3, 22.4, 13.2,  5.6,
#         9.6, 23.8,  8.7, 18. , 22.3, 19.6, 12.7,  6.9,  9.5,  3.2, 11.5,
#        15.9, 15.5, 14.8, 19.4, 19.7, 17.2, 19.2, 11.6, 17.3, 11.7, 12.8,
#        21.5, 21.7,  9.3, 23.7,  9.7, 18.9, 10.8, 11.9,  5.3, 17.3, 19. ,
#        21.8, 11.5,  9.6, 11. , 23.2, 25.5, 15.9, 11.7, 13.2, 15.2,  7.2,
#        13.6, 24.4, 25.4,  9.5,  6.6, 19.8])

# %% [markdown]
# Selesaikan OLS
#
# $$
# \theta_{\text{optimum}} = (X^{T}X)^{-1} X^{T} y
# $$

# %%
theta_ols = np.linalg.inv(X_ols.T @ X_ols) @ X_ols.T @ y_ols # @ adalah madmul / matrix multipliaction / perkalian matrix

theta_ols

# hasilnya ([ TV, Radio, Newspaper])
# Out:
# array([ 4.55889680e-02,  1.86533886e-01, -6.30319159e-04,  2.92422679e+00])

# %% [markdown]
# **Predict & Evaluate**

# %% [markdown]
# Untuk memprediksi, menggunakan persamaan akhirnya

# %%
def lr_ols(X):
    y = np.column_stack([X, np.ones(len(X))]) @ theta_ols

    return y

# %%
# Buat prediksi
y_train_pred_ols = lr_ols(X = X_train)

# %%
summary_train_ols_pred = pd.DataFrame({"actual": y_train,
                                       "prediction": y_train_pred_ols})

summary_train_ols_pred.head()
# Out:
#      actual  prediction
# 24      9.7    8.103212
# 150    16.1   18.290549
# 114    14.6   15.197324
# 33     17.4   18.763145
# 23     15.5   16.468096

# %%
# Plot hasil
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

ax[0].scatter(summary_train_pred["actual"], summary_train_pred["prediction"])
ax[0].plot([0, 30], [0, 30], "--k")

ax[0].set_xlabel("Actual")
ax[0].set_ylabel("Prediction")
ax[0].set_xlim(0, 30)
ax[0].set_ylim(0, 30)

ax[1].scatter(summary_train_ols_pred["actual"], summary_train_ols_pred["prediction"])
ax[1].plot([0, 30], [0, 30], "--k")

ax[1].set_xlabel("Actual")
ax[1].set_ylabel("Prediction")
ax[1].set_xlim(0, 30)
ax[1].set_ylim(0, 30)

plt.show()

# %% [markdown]
# - prediksi semakin bagus apabila titik dekat dengan garis putus-putus

# %%
# Cari MSE
prediction_train_ols_mse = mean_squared_error(y_train_pred_ols, y_train)
print(prediction_train_ols_mse)
# Out:
# 2.9376246773049877

# %%
# Cari perbandingan dengan baseline
comparison_mse = 100*(baseline_mse - prediction_train_ols_mse) / baseline_mse
print(f"MSE turun {comparison_mse:.2f} %")
# Out:
# MSE turun 88.74 %

# %% [markdown]
# ---
# # **Apa harus dinormalisasi?**
# Standarisasi dan normalisasi konteksnya sama

# %% [markdown]
# Lakukan standardisasi X_train & X_test

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Buat objek scaler
scaler = StandardScaler()

# Fit pada data train
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Transform scaler pada X_train & X_test
X_train_scaled = scaler.transform(X_train)
X_train_scaled = pd.DataFrame(X_train_scaled)
X_train_scaled.columns = X_train.columns
X_train_scaled.index = X_train.index

X_test_scaled = scaler.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled)
X_test_scaled.columns = X_test.columns
X_test_scaled.index = X_test.index

# %% [markdown]
# Lakukan fitting

# %%
# Buat objek
lr_scaled = LinearRegression()

# %%
# Lakukan cross validation
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(estimator = lr_scaled,
                         X = X_train_scaled,
                         y = y_train,
                         cv = 5,
                         scoring = "neg_mean_squared_error")

# %%
scores
# Out:
# array([-1.95519805, -5.9288142 , -2.14412184, -3.06528874, -2.98933228])

# %%
lr_scaled_cv_scores = - np.mean(scores)
print(lr_scaled_cv_scores)
# Out:
# 3.216551023140723

# %%
# Lakukan Fitting Data
lr_scaled.fit(X = X_train_scaled,
              y = y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Predict & Evaluate**

# %%
# Buat prediksi
y_scaled_pred = lr_scaled.predict(X_train_scaled)

# %%
summary_train_scaled_pred = pd.DataFrame({"actual": y_train,
                                          "prediction": y_scaled_pred})

summary_train_scaled_pred.head()
# Out:
#      actual  prediction
# 24      9.7    8.103212
# 150    16.1   18.290549
# 114    14.6   15.197324
# 33     17.4   18.763145
# 23     15.5   16.468096

# %%
# Plot hasil
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

ax[0].scatter(summary_train_pred["actual"], summary_train_pred["prediction"])
ax[0].plot([0, 30], [0, 30], "--k")

ax[0].set_xlabel("Actual")
ax[0].set_ylabel("Prediction")
ax[0].set_xlim(0, 30)
ax[0].set_ylim(0, 30)

ax[1].scatter(summary_train_scaled_pred["actual"], summary_train_scaled_pred["prediction"])
ax[1].plot([0, 30], [0, 30], "--k")

ax[1].set_xlabel("Actual")
ax[1].set_ylabel("Prediction")
ax[1].set_xlim(0, 30)
ax[1].set_ylim(0, 30)

plt.show()

# %% [markdown]
# - prediksi semakin bagus apabila titik dekat dengan garis putus-putus

# %%
# Cari MSE
prediction_train_scaled_mse = mean_squared_error(y_scaled_pred, y_train)
print(prediction_train_scaled_mse)
# Out:
# 2.9376246773049877

# %%
# Cari perbandingan dengan baseline
comparison_mse = 100*(baseline_mse - prediction_train_scaled_mse) / baseline_mse
print(f"MSE turun {comparison_mse:.2f} %")
# Out:
# MSE turun 88.74 %

# %% [markdown]
# **Tampilkan hasil linear regression**

# %%
# Koefisien/slope linear regression
lr_scaled.coef_
# Out:
# array([ 3.90372233,  2.7816998 , -0.01399175])

# %%
# Intercept linear regression
lr_scaled.intercept_
# Out:
# np.float64(14.095000000000002)
